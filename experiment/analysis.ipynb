# %% [markdown]
# # Init the data frame

# %%
from unicodedata import name
from pandas import Series, DataFrame
import pandas as pd

timelimit = 60

index_template = ["sat", "unsat", "unknown", "error", "timeout", "time(ms)"]

class ResultDic:
    name: str
    resdic: dict

    def __init__(self, name: str) -> None:
        self.name = name
        self.resdic = {}

    def update(self, colname: str, onedata: list):
        self.resdic[colname] = onedata

    def isempty(self):
        return self.resdic == {}


class ResultDf:
    resdics: dict[str, ResultDic]

    def __init__(self, resultfiles: list[str]) -> None:
        self.resdics = {file: ResultDic(file) for file in resultfiles}

    def update(self, backend: str, colname: str, onedata: list):
        """update result dataframe for a backend

        Args:
            backend (str): name of backend
            colname (str): name of column
            onedata (list): one column data
        """
        self.resdics[backend].update(colname, onedata)

    def get_df(self) -> list[DataFrame]:
        """convert to dataframe

        Returns:
            res (list[Dataframe]): generator of dataframe
        """
        df_list = []
        for resdic in self.resdics.values():
            if resdic.isempty():
                print(f"Warning: {resdic.name} is empty")
                continue
            res = DataFrame(resdic.resdic, index=index_template).astype("int64").T
            res.name = resdic.name
            df_list.append(res)
        return df_list

# %% [markdown]
# #  Get files containing the result

# %%
import os
import glob

commit = '23-03-02_11:47:58unary_generate_normal_findstring'

dirname = os.path.abspath("")

analyzed_files = glob.glob(f"{dirname}/res/{commit}/*_log.txt", recursive=True)
print(analyzed_files)
# Out:
# ['/home/hudh/github/ostrich/experiment/res/23-03-02_11:47:58unary_generate_normal_findstring/unary_log.txt']

# %% [markdown]
# # Parse the files

# %%
import re


def parse_single_result(result: str) -> list[int | float]:
    SAT_RE = re.compile("^sat", re.M)
    UNSAT_RE = re.compile("^unsat", re.M)
    UNKNOWN_RE = re.compile("^unknown|^--Unknown", re.M)
    ERR_RE = re.compile("^\(error |^--Exception", re.M | re.I)
    TIMEOUT_RE = re.compile("^Timeout", re.M)
    TIME_RE = re.compile("^Time: (.*)ms", re.M)
    sat = unsat = timeout = unknown = err = timeused = 0
    if SAT_RE.search(result):
        sat = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif UNSAT_RE.search(result):
        unsat = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif UNKNOWN_RE.search(result):
        unknown = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif TIMEOUT_RE.search(result):
        timeout = 1
        timeused = float(TIME_RE.search(result).group(1))
    # elif ERR_RE.search(result):
    else:
        err = 1
        timeused = float(TIME_RE.search(result).group(1))
    onedata = [sat, unsat, unknown, err, timeout, timeused]
    return onedata


def parse_files(filenames: list[str]) -> ResultDf:
    """parse a file to get data

    Args:
        filename (str): file name

    Returns:
        ResultDf: result dataframe
    """
    basenames = [os.path.basename(filename) for filename in filenames]
    res = ResultDf(basenames)
    for filename in filenames:
        # backend = re.search(f"([a-z]+)_log.txt", filename).group(1)
        backend = os.path.basename(filename)
        INSTANCE_RE = re.compile("^Running \[(.*)\]", re.M)
        with open(filename, "r") as f:
            lines = f.read()
            results = lines.split("----splitter----")
            for result in results[:-1]:
                instance = INSTANCE_RE.search(result).group(1)
                onedata = parse_single_result(result)
                if(onedata[4] > 0):
                    print(instance.replace("experiment", "."))
                res.update(backend, instance, onedata)
    return res


res = parse_files(analyzed_files)


def get_final_df(res: ResultDf):
    """get final dataframe

    Args:
        res (ResultDf): result dataframe

    Returns:
        DataFrame: final dataframe
    """
    dataframes: list[DataFrame] = []
    for df in res.get_df():
        dic = {}
        dic["avg_time(sat) ms"] = [df[df["sat"] == 1]["time(ms)"].mean()]
        dic["avg_time(unsat) ms"] = [df[df["unsat"] == 1]["time(ms)"].mean()]
        dic["avg_time(total) ms"] = [df["time(ms)"].mean()]
        avgf = DataFrame(dic).T.fillna(0)
        sumf = df.sum().drop(index="time(ms)")
        concatf = pd.concat([sumf, avgf]).astype("int64")
        concatf.name = df.name
        dataframes.append(concatf)

    index = [i for i in range(len(dataframes))]
    dfnames = [df.name for df in dataframes]
    resdf = pd.concat(dataframes, axis=1, ignore_index=True).rename(
        columns=dict(zip(index, dfnames))
    )
    return resdf


get_final_df(res)
# Out:
# ./benchmarks/sanitized/count_benchmark_generate/cnt_small/instance1.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_small/instance259.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_small/instance508.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_small/instance620.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_small/instance715.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance30776.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance31677.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance32042.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance14957.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance15073.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance32285.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance48326.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance89.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance32851.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance15696.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance169.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance33126.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance49317.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance49944.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance49969.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance1277.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance1612.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance17650.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance17927.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance3249.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance3876.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance51163.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance36407.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance5517.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance5660.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance37291.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance5828.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance37462.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance52629.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance6716.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance53264.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance8244.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance54810.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance20156.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance40039.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance8979.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance9740.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance9982.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance10508.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance10547.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance54930.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance42259.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance42818.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance11876.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance56142.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance12855.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance24259.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance56790.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance13399.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance57096.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance24689.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance13759.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance57385.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance57406.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance25960.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance45358.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance46144.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance27614.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance46448.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance46583.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance28355.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance28586.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance28773.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance28898.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance29744.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_small/instance30448.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_large/instance521.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_large/instance545.smt2
# ./benchmarks/sanitized/count_benchmark_generate/cnt_large/instance816.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_large/instance12.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_large/instance22.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_large/instance27.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_large/instance47.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_large/instance95.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance84.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance98.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance99.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance172.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance192.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance213.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance502.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance516.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance517.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance610.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance616.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance624.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance657.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance741.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance769.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance924.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance985.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1038.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1076.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1148.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1177.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1230.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1252.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1302.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1382.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1383.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1414.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1431.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1457.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1458.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1568.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1590.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1633.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1714.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1731.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance1760.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance2018.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance2021.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance2046.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance2194.smt2
# ./benchmarks/sanitized/count_benchmark_generate/stackoverflow_large/instance2361.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance203.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1038.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1331.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1403.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1657.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1968.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance1976.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance2126.smt2
# ./benchmarks/sanitized/count_benchmark_generate/regexlib_small/instance2143.smt2
#                     unary_log.txt
# sat                         21072
# unsat                       19402
# unknown                        22
# error                          47
# timeout                       129
# avg_time(sat) ms             2041
# avg_time(unsat) ms           1664
# avg_time(total) ms           2072
