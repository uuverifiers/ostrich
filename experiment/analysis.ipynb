# %% [markdown]
# # Init the data frame

# %%
from unicodedata import name
from pandas import Series, DataFrame
import pandas as pd

timelimit = 60

index_template = ["sat", "unsat", "unknown", "error", "timeout", "time(ms)"]

class ResultDic:
    name: str
    resdic: dict

    def __init__(self, name: str) -> None:
        self.name = name
        self.resdic = {}

    def update(self, colname: str, onedata: list):
        self.resdic[colname] = onedata

    def isempty(self):
        return self.resdic == {}


class ResultDf:
    resdics: dict[str, ResultDic]

    def __init__(self, resultfiles: list[str]) -> None:
        self.resdics = {file: ResultDic(file) for file in resultfiles}

    def update(self, backend: str, colname: str, onedata: list):
        """update result dataframe for a backend

        Args:
            backend (str): name of backend
            colname (str): name of column
            onedata (list): one column data
        """
        self.resdics[backend].update(colname, onedata)

    def get_df(self) -> list[DataFrame]:
        """convert to dataframe

        Returns:
            res (list[Dataframe]): generator of dataframe
        """
        df_list = []
        for resdic in self.resdics.values():
            if resdic.isempty():
                print(f"Warning: {resdic.name} is empty")
                continue
            res = DataFrame(resdic.resdic, index=index_template).astype("int64").T
            res.name = resdic.name
            df_list.append(res)
        return df_list

# %% [markdown]
# #  Get files containing the result

# %%
import os
import glob

commit = '23-02-24_09:18:11cvc5_small'

dirname = os.path.abspath("")

analyzed_files = glob.glob(f"{dirname}/res/{commit}/*_log.txt", recursive=True)
print(analyzed_files)
# Out:
# ['/home/hudh/github/ostrich/experiment/res/23-02-24_09:18:11cvc5_small/cvc5_log.txt']

# %% [markdown]
# # Parse the files

# %%
import re


def parse_single_result(result: str) -> list[int | float]:
    SAT_RE = re.compile("^sat", re.M)
    UNSAT_RE = re.compile("^unsat", re.M)
    UNKNOWN_RE = re.compile("^unknown|^--Unknown", re.M)
    ERR_RE = re.compile("^\(error |^--Exception", re.M | re.I)
    TIMEOUT_RE = re.compile("^Timeout", re.M)
    TIME_RE = re.compile("^Time: (.*)ms", re.M)
    sat = unsat = timeout = unknown = err = timeused = 0
    if SAT_RE.search(result):
        sat = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif UNSAT_RE.search(result):
        unsat = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif UNKNOWN_RE.search(result):
        unknown = 1
        timeused = float(TIME_RE.search(result).group(1))
    elif TIMEOUT_RE.search(result):
        timeout = 1
        timeused = float(TIME_RE.search(result).group(1))
    # elif ERR_RE.search(result):
    else:
        err = 1
        timeused = float(TIME_RE.search(result).group(1))
    onedata = [sat, unsat, unknown, err, timeout, timeused]
    return onedata


def parse_files(filenames: list[str]) -> ResultDf:
    """parse a file to get data

    Args:
        filename (str): file name

    Returns:
        ResultDf: result dataframe
    """
    basenames = [os.path.basename(filename) for filename in filenames]
    res = ResultDf(basenames)
    for filename in filenames:
        # backend = re.search(f"([a-z]+)_log.txt", filename).group(1)
        backend = os.path.basename(filename)
        INSTANCE_RE = re.compile("^Running \[(.*)\]", re.M)
        with open(filename, "r") as f:
            lines = f.read()
            results = lines.split("----splitter----")
            for result in results[:-1]:
                instance = INSTANCE_RE.search(result).group(1)
                onedata = parse_single_result(result)
                if(onedata[4] > 0):
                    print(instance)
                res.update(backend, instance, onedata)
    return res


res = parse_files(analyzed_files)


def get_final_df(res: ResultDf):
    """get final dataframe

    Args:
        res (ResultDf): result dataframe

    Returns:
        DataFrame: final dataframe
    """
    dataframes: list[DataFrame] = []
    for df in res.get_df():
        dic = {}
        dic["avg_time(sat) ms"] = [df[df["sat"] == 1]["time(ms)"].mean()]
        dic["avg_time(unsat) ms"] = [df[df["unsat"] == 1]["time(ms)"].mean()]
        dic["avg_time(total) ms"] = [df["time(ms)"].mean()]
        avgf = DataFrame(dic).T.fillna(0)
        sumf = df.sum().drop(index="time(ms)")
        concatf = pd.concat([sumf, avgf]).astype("int64")
        concatf.name = df.name
        dataframes.append(concatf)

    index = [i for i in range(len(dataframes))]
    dfnames = [df.name for df in dataframes]
    resdf = pd.concat(dataframes, axis=1, ignore_index=True).rename(
        columns=dict(zip(index, dfnames))
    )
    return resdf


get_final_df(res)
# Out:
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance426.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8943.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8217.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3421.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6992.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3529.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2007.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1503.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8020.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7382.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5632.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4127.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4889.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9940.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9126.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9137.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5707.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8498.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9270.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9708.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6042.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance512.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2792.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9925.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2168.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4622.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6564.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6998.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1990.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9097.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6056.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8766.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3169.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3917.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2717.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2351.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3535.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1532.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5733.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2260.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7034.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9314.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5272.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4724.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6262.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6431.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5476.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9046.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5088.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4766.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6258.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3095.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance421.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4357.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6151.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3754.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1655.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1769.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9066.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7328.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8198.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8948.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5291.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1929.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6215.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7358.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7941.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8358.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7360.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6619.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5367.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2772.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1762.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8902.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance304.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9372.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2586.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7706.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7993.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3663.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8306.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2545.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3211.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2400.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1041.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4982.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6993.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2529.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4853.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance702.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8427.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7988.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7926.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6264.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7766.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9937.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance185.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9059.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance6968.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance307.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1429.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance556.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5554.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7528.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1167.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5364.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance848.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9351.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance1101.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance455.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9566.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3491.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance7647.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance2150.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9244.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance9593.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3599.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5898.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8706.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance8073.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance5991.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance3982.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance946.smt2
# experiment/benchmarks/sanitized/count_benchmark_others/small/instance4569.smt2
#                     cvc5_log.txt
# sat                         3764
# unsat                       3375
# unknown                        0
# error                         43
# timeout                      124
# avg_time(sat) ms             193
# avg_time(unsat) ms           231
# avg_time(total) ms          1227
